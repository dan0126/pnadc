# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
import plotly.express as px

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# LEGENDAS

"V2007", # Sexo
"V2009"  # Idade do morador na data de referência
"V2010"  # Cor/raça
"V3003A" # Qual é o curso que frequenta atualmente 
"V3001"  # Sabe ler e escrever
"VD4001" # Economicamente ativa/não (Força de trabalho)
"VD4002" # Ocupadas/ não ocupadas - não incluso
"VD4020" # Redimentos mensal de trabalho
"VD5002" # Renda domiciliar per capita - não incluso
"V4010"  # Profissão principa(função, cargo)
"V3009A" # Qual é o curso mais elevado que já frequentou

# %%
df_2016 = pd.read_csv('../input/c1-pnadc/PNADc2016.csv')
df_2017 = pd.read_csv('../input/c1-pnadc/PNADc2017.csv')
df_2018 = pd.read_csv('../input/c1-pnadc/PNADc2018.csv')
df_2019 = pd.read_csv('../input/c1-pnadc/PNADc2019.csv')

# %%
df_2019.columns

# %%
deletar = ['Unnamed: 0',
           'Trimestre',
           'UPA',
           'Estrato',
           'V1008',
           'V1030',
           "VD5002",
           'V1031',
           'V4041',
           'posest',
           'V2003', 
           'CO1',
           'CO1e',
           'CO2',
           'CO2e',
           'CO3']

df_2016 = df_2016.drop(deletar, axis=1)
df_2017 = df_2017.drop(deletar, axis=1)
df_2018 = df_2018.drop(deletar, axis=1)
df_2019 = df_2019.drop(deletar, axis=1)

# %%
df_2019.columns

# %%
nome = ['Ano',    #Ano
        'UF',     #UF
        'Sexo',   #V2007
        'Idade',  #V2009 
        'Cor',    #V2010
        'Le/escreve',      #V3001
        'Educação atual',  #V3003A 
        'Educação feita',  #V3009A 
        'Profissao',       #V4010
        'Economicamente ativa/não',  #VD4001
        'Ocupado/não',               #VD4002
        'Redimentos de trabalho']    #VD4020


df_2016.columns = nome
df_2017.columns = nome
df_2018.columns = nome
df_2019.columns = nome

# %% [markdown]
# # Ano 2019

# %%
df_2019.columns.to_list()

# %%
df_2019.dtypes

# %%
df_2019.count()

# %%
df_2019['Economicamente ativa/não'].value_counts()

# %%
df_2019['Educação atual'].value_counts()

# %%
df_2019['Educação feita'].value_counts()

# %%
df_2019['Le/escreve'].value_counts()

# %%
df_2019['Cor'].value_counts()

# %%
df_2019[['Cor','Sexo']].value_counts()

# %%
idade = df_2019['Idade'].to_list()

i10=np.percentile(idade,10)
i20=np.percentile(idade,20)
i25=np.percentile(idade,25)
i30=np.percentile(idade,30)
i40=np.percentile(idade,40)
i50=np.percentile(idade,50)
i60=np.percentile(idade,60)
i70=np.percentile(idade,70)
i80=np.percentile(idade,80)
i90=np.percentile(idade,90)
i95=np.percentile(idade,95)
i99=np.percentile(idade,99)

print("\n[Ano 2019] Distribuição da idade da população brasileira")

print("\n10th Percentile: ",i10)
print("\n20th Percentile: ",i20)
print("\n25th Percentile: ",i25)
print("\n30th Percentile: ",i30)
print("\n40th Percentile: ",i40)
print("\n50th Percentile: ",i50)
print("\n60th Percentile: ",i60)
print("\n70th Percentile: ",i70)
print("\n80th Percentile: ",i80)
print("\n90th Percentile: ",i90)
print("\n95th Percentile: ",i95)
print("\n99th Percentile: ",i99)

# %%
rend = df_2019['Redimentos de trabalho'].dropna().to_list()

rp10=np.percentile(rend,10)
rp20=np.percentile(rend,20)
rp25=np.percentile(rend,25)
rp30=np.percentile(rend,30)
rp40=np.percentile(rend,40)
rp50=np.percentile(rend,50)
rp60=np.percentile(rend,60)
rp70=np.percentile(rend,70)
rp80=np.percentile(rend,80)
rp90=np.percentile(rend,90)
rp95=np.percentile(rend,95)
rp99=np.percentile(rend,99)

print("\n[Ano 2019] Redimento de trabalho mensal da população brasileira em reais")
print("Quantidade de respondentes", len(rend),"de",len(df_2019['Redimentos de trabalho'].to_list()))
print("Quantidade de pessoas na força de trabalho", 213493)
print("\n10th Percentile: ",rp10)
print("\n20th Percentile: ",rp20)
print("\n25th Percentile: ",rp25)
print("\n30th Percentile: ",rp30)
print("\n40th Percentile: ",rp40)
print("\n50th Percentile: ",rp50)
print("\n60th Percentile: ",rp60)
print("\n70th Percentile: ",rp70)
print("\n80th Percentile: ",rp80)
print("\n90th Percentile: ",rp90)
print("\n95th Percentile: ",rp95)
print("\n99th Percentile: ",rp99)

# %%
df_2019['Ocupado/não'].value_counts()

# %%
#189836 respondetes sobre a sua profissão
df_2019['Profissao'].value_counts().head(20)

# %% [markdown]
# # [Amarelos] Dados mais oraganizados

# %% [markdown]
# **Ano 2019**

# %%
df_asia = df_2019[df_2019['Cor'].str.contains('Amarela')]

# %%
df_asia.count()

# %%
df_asia['UF'].value_counts()

# %%
idade = df_asia['Idade'].to_list()

i10=np.percentile(idade,10)
i20=np.percentile(idade,20)
i25=np.percentile(idade,25)
i30=np.percentile(idade,30)
i40=np.percentile(idade,40)
i50=np.percentile(idade,50)
i60=np.percentile(idade,60)
i70=np.percentile(idade,70)
i80=np.percentile(idade,80)
i90=np.percentile(idade,90)
i95=np.percentile(idade,95)
i99=np.percentile(idade,99)

print("\n[Ano 2019] Distribuição da idade da população amarela")

print("\n10th Percentile: ",i10)
print("\n20th Percentile: ",i20)
print("\n25th Percentile: ",i25)
print("\n30th Percentile: ",i30)
print("\n40th Percentile: ",i40)
print("\n50th Percentile: ",i50)
print("\n60th Percentile: ",i60)
print("\n70th Percentile: ",i70)
print("\n80th Percentile: ",i80)
print("\n90th Percentile: ",i90)
print("\n95th Percentile: ",i95)
print("\n99th Percentile: ",i99)

# %%
df_asia['Educação feita'].value_counts()

# %%
df_asia['Educação atual'].value_counts()

# %%
df_asia['Economicamente ativa/não'].value_counts()

# %%
rend = df_asia['Redimentos de trabalho'].dropna().to_list()

rp10=np.percentile(rend,10)
rp20=np.percentile(rend,20)
rp25=np.percentile(rend,25)
rp30=np.percentile(rend,30)
rp40=np.percentile(rend,40)
rp50=np.percentile(rend,50)
rp60=np.percentile(rend,60)
rp70=np.percentile(rend,70)
rp80=np.percentile(rend,80)
rp90=np.percentile(rend,90)
rp95=np.percentile(rend,95)
rp99=np.percentile(rend,99)

print("\n[Ano 2019] Redimento de trabalho mensal da população amarela em reais")
print("Quantidade de respondentes", len(rend),"de",len(df_asia['Redimentos de trabalho'].to_list()))
print("Quantidade de pessoas na força de trabalho", 1201)
print("\n10th Percentile: ",rp10)
print("\n20th Percentile: ",rp20)
print("\n25th Percentile: ",rp25)
print("\n30th Percentile: ",rp30)
print("\n40th Percentile: ",rp40)
print("\n50th Percentile: ",rp50)
print("\n60th Percentile: ",rp60)
print("\n70th Percentile: ",rp70)
print("\n80th Percentile: ",rp80)
print("\n90th Percentile: ",rp90)
print("\n95th Percentile: ",rp95)
print("\n99th Percentile: ",rp99)

# %%
df_asia['Le/escreve'].value_counts()

# %%
df_asia['Sexo'].value_counts()

# %%
df_asia['Ocupado/não'].value_counts()

# %%
#1098 respondentes
df_asia['Profissao'].value_counts().head(20)

# %% [markdown]
# Mulheres

# %%
df_asia_m = df_asia[df_asia['Sexo'].str.contains('Mulher')]

# %%
idade = df_asia_m['Idade'].to_list()

i10=np.percentile(idade,10)
i20=np.percentile(idade,20)
i25=np.percentile(idade,25)
i30=np.percentile(idade,30)
i40=np.percentile(idade,40)
i50=np.percentile(idade,50)
i60=np.percentile(idade,60)
i70=np.percentile(idade,70)
i80=np.percentile(idade,80)
i90=np.percentile(idade,90)
i95=np.percentile(idade,95)
i99=np.percentile(idade,99)

print("\n[Ano 2019] Distribuição da idade das mulheres amarelas")

print("\n10th Percentile: ",i10)
print("\n20th Percentile: ",i20)
print("\n25th Percentile: ",i25)
print("\n30th Percentile: ",i30)
print("\n40th Percentile: ",i40)
print("\n50th Percentile: ",i50)
print("\n60th Percentile: ",i60)
print("\n70th Percentile: ",i70)
print("\n80th Percentile: ",i80)
print("\n90th Percentile: ",i90)
print("\n95th Percentile: ",i95)
print("\n99th Percentile: ",i99)

# %%
df_asia_m['Educação atual'].value_counts()

# %%
df_asia_m['Educação feita'].value_counts()

# %%
df_asia_m['Economicamente ativa/não'].value_counts()

# %%
rend = df_asia_m['Redimentos de trabalho'].dropna().to_list()

rp10=np.percentile(rend,10)
rp20=np.percentile(rend,20)
rp25=np.percentile(rend,25)
rp30=np.percentile(rend,30)
rp40=np.percentile(rend,40)
rp50=np.percentile(rend,50)
rp60=np.percentile(rend,60)
rp70=np.percentile(rend,70)
rp80=np.percentile(rend,80)
rp90=np.percentile(rend,90)
rp95=np.percentile(rend,95)
rp99=np.percentile(rend,99)

print("\n[Ano 2019] Redimento de trabalho mensal das mulheres amarelas em reais")
print("Quantidade de respondentes", len(rend),"de",len(df_asia_m['Redimentos de trabalho'].to_list()))
print("Quantidade de pessoas na força de trabalho", 576)
print("\n10th Percentile: ",rp10)
print("\n20th Percentile: ",rp20)
print("\n25th Percentile: ",rp25)
print("\n30th Percentile: ",rp30)
print("\n40th Percentile: ",rp40)
print("\n50th Percentile: ",rp50)
print("\n60th Percentile: ",rp60)
print("\n70th Percentile: ",rp70)
print("\n80th Percentile: ",rp80)
print("\n90th Percentile: ",rp90)
print("\n95th Percentile: ",rp95)
print("\n99th Percentile: ",rp99)

# %%
df_asia_m['Ocupado/não'].value_counts()

# %%
#517 respondentes
df_asia_m['Profissao'].value_counts().head(20)

# %% [markdown]
# Homens

# %%
df_asia_h = df_asia[df_asia['Sexo'].str.contains('Homem')]

# %%
idade = df_asia_h['Idade'].to_list()

i10=np.percentile(idade,10)
i20=np.percentile(idade,20)
i25=np.percentile(idade,25)
i30=np.percentile(idade,30)
i40=np.percentile(idade,40)
i50=np.percentile(idade,50)
i60=np.percentile(idade,60)
i70=np.percentile(idade,70)
i80=np.percentile(idade,80)
i90=np.percentile(idade,90)
i95=np.percentile(idade,95)
i99=np.percentile(idade,99)

print("\n[Ano 2019] Distribuição da idade da população amarela")

print("\n10th Percentile: ",i10)
print("\n20th Percentile: ",i20)
print("\n25th Percentile: ",i25)
print("\n30th Percentile: ",i30)
print("\n40th Percentile: ",i40)
print("\n50th Percentile: ",i50)
print("\n60th Percentile: ",i60)
print("\n70th Percentile: ",i70)
print("\n80th Percentile: ",i80)
print("\n90th Percentile: ",i90)
print("\n95th Percentile: ",i95)
print("\n99th Percentile: ",i99)

# %%
df_asia_h['Educação feita'].value_counts()

# %%
df_asia_h['Educação atual'].value_counts()

# %%
df_asia_h['Economicamente ativa/não'].value_counts()

# %%
rend = df_asia_h['Redimentos de trabalho'].dropna().to_list()

rp10=np.percentile(rend,10)
rp20=np.percentile(rend,20)
rp25=np.percentile(rend,25)
rp30=np.percentile(rend,30)
rp40=np.percentile(rend,40)
rp50=np.percentile(rend,50)
rp60=np.percentile(rend,60)
rp70=np.percentile(rend,70)
rp80=np.percentile(rend,80)
rp90=np.percentile(rend,90)
rp95=np.percentile(rend,95)
rp99=np.percentile(rend,99)

print("\n[Ano 2019] Redimento de trabalho mensal dos homens amarelos em reais")
print("Quantidade de respondentes", len(rend),"de",len(df_asia_h['Redimentos de trabalho'].to_list()))
print("Quantidade de pessoas na força de trabalho", 625)
print("\n10th Percentile: ",rp10)
print("\n20th Percentile: ",rp20)
print("\n25th Percentile: ",rp25)
print("\n30th Percentile: ",rp30)
print("\n40th Percentile: ",rp40)
print("\n50th Percentile: ",rp50)
print("\n60th Percentile: ",rp60)
print("\n70th Percentile: ",rp70)
print("\n80th Percentile: ",rp80)
print("\n90th Percentile: ",rp90)
print("\n95th Percentile: ",rp95)
print("\n99th Percentile: ",rp99)

# %%
df_asia_h['Ocupado/não'].value_counts()

# %%
#581 respondentes
df_asia_h['Profissao'].value_counts().head(20)

# %% [markdown]
# # Explorando cargos ocupados pela população amarela na graduação

# %%
df_asia_p = df_asia[df_asia['Ocupado/não'].str.contains('Pessoas ocupadas',na=False)]

# %%
graduando_p =  df_asia[df_asia['Educação atual'].str.contains('Superior - graduação',na=False)]

# %%
graduando_p['Economicamente ativa/não'].value_counts()

# %%
graduando_p['Profissao'].value_counts()

# %%
rend = graduando_p['Redimentos de trabalho'].dropna().to_list()

rp10=np.percentile(rend,10)
rp20=np.percentile(rend,20)
rp25=np.percentile(rend,25)
rp30=np.percentile(rend,30)
rp40=np.percentile(rend,40)
rp50=np.percentile(rend,50)
rp60=np.percentile(rend,60)
rp70=np.percentile(rend,70)
rp80=np.percentile(rend,80)
rp90=np.percentile(rend,90)
rp95=np.percentile(rend,95)
rp99=np.percentile(rend,99)

print("\n[Ano 2019] Redimento de trabalho mensal dos graduandos amarelos em reais")
print("Quantidade de respondentes", len(rend),"de",len(graduando_p['Redimentos de trabalho'].to_list()))
print("Quantidade de pessoas na força de trabalho", 67)
print("\n10th Percentile: ",rp10)
print("\n20th Percentile: ",rp20)
print("\n25th Percentile: ",rp25)
print("\n30th Percentile: ",rp30)
print("\n40th Percentile: ",rp40)
print("\n50th Percentile: ",rp50)
print("\n60th Percentile: ",rp60)
print("\n70th Percentile: ",rp70)
print("\n80th Percentile: ",rp80)
print("\n90th Percentile: ",rp90)
print("\n95th Percentile: ",rp95)
print("\n99th Percentile: ",rp99)

# %%
idade = graduando_p['Idade'].to_list()

i10=np.percentile(idade,10)
i20=np.percentile(idade,20)
i25=np.percentile(idade,25)
i30=np.percentile(idade,30)
i40=np.percentile(idade,40)
i50=np.percentile(idade,50)
i60=np.percentile(idade,60)
i70=np.percentile(idade,70)
i80=np.percentile(idade,80)
i90=np.percentile(idade,90)
i95=np.percentile(idade,95)
i99=np.percentile(idade,99)

print("\n[Ano 2019] Distribuição da idade da população amarela que ainda é graduando")

print("\n10th Percentile: ",i10)
print("\n20th Percentile: ",i20)
print("\n25th Percentile: ",i25)
print("\n30th Percentile: ",i30)
print("\n40th Percentile: ",i40)
print("\n50th Percentile: ",i50)
print("\n60th Percentile: ",i60)
print("\n70th Percentile: ",i70)
print("\n80th Percentile: ",i80)
print("\n90th Percentile: ",i90)
print("\n95th Percentile: ",i95)
print("\n99th Percentile: ",i99)

# %% [markdown]
# # Explorando cargos ocupados pela população amarela já graduados

# %%
graduando_pf =  df_asia[df_asia['Educação feita'].str.contains('Superior - graduação',na=False)]
graduando_pf

# %%
graduando_pf['Economicamente ativa/não'].value_counts()

# %%
graduando_pf['Profissao'].value_counts().head(30)

# %%
rend = graduando_pf['Redimentos de trabalho'].dropna().to_list()

rp10=np.percentile(rend,10)
rp20=np.percentile(rend,20)
rp25=np.percentile(rend,25)
rp30=np.percentile(rend,30)
rp40=np.percentile(rend,40)
rp50=np.percentile(rend,50)
rp60=np.percentile(rend,60)
rp70=np.percentile(rend,70)
rp80=np.percentile(rend,80)
rp90=np.percentile(rend,90)
rp95=np.percentile(rend,95)
rp99=np.percentile(rend,99)

print("\n[Ano 2019] Redimento de trabalho mensal dos já graduados amarelos em reais")
print("Quantidade de respondentes", len(rend),"de",len(graduando_pf['Redimentos de trabalho'].to_list()))
print("Quantidade de pessoas na força de trabalho", 283)
print("\n10th Percentile: ",rp10)
print("\n20th Percentile: ",rp20)
print("\n25th Percentile: ",rp25)
print("\n30th Percentile: ",rp30)
print("\n40th Percentile: ",rp40)
print("\n50th Percentile: ",rp50)
print("\n60th Percentile: ",rp60)
print("\n70th Percentile: ",rp70)
print("\n80th Percentile: ",rp80)
print("\n90th Percentile: ",rp90)
print("\n95th Percentile: ",rp95)
print("\n99th Percentile: ",rp99)

# %%
idade = graduando_pf['Idade'].to_list()

i10=np.percentile(idade,10)
i20=np.percentile(idade,20)
i25=np.percentile(idade,25)
i30=np.percentile(idade,30)
i40=np.percentile(idade,40)
i50=np.percentile(idade,50)
i60=np.percentile(idade,60)
i70=np.percentile(idade,70)
i80=np.percentile(idade,80)
i90=np.percentile(idade,90)
i95=np.percentile(idade,95)
i99=np.percentile(idade,99)

print("\n[Ano 2019] Distribuição da idade da população amarela que já se formou")

print("\n10th Percentile: ",i10)
print("\n20th Percentile: ",i20)
print("\n25th Percentile: ",i25)
print("\n30th Percentile: ",i30)
print("\n40th Percentile: ",i40)
print("\n50th Percentile: ",i50)
print("\n60th Percentile: ",i60)
print("\n70th Percentile: ",i70)
print("\n80th Percentile: ",i80)
print("\n90th Percentile: ",i90)
print("\n95th Percentile: ",i95)
print("\n99th Percentile: ",i99)

# %% [markdown]
# # ANO 2018

# %%
df_2018.columns.to_list()

# %%
df_2018.count()

# %%
df_2018['Economicamente ativa/não'].value_counts()

# %%
df_2018['Educação atual'].value_counts()

# %%
df_2018['Educação feita'].value_counts()

# %%
df_2018['Le/escreve'].value_counts()

# %%
df_2018['Cor'].value_counts()

# %%
df_2018[['Cor','Sexo']].value_counts()

# %%
idade = df_2018['Idade'].to_list()

i10=np.percentile(idade,10)
i20=np.percentile(idade,20)
i25=np.percentile(idade,25)
i30=np.percentile(idade,30)
i40=np.percentile(idade,40)
i50=np.percentile(idade,50)
i60=np.percentile(idade,60)
i70=np.percentile(idade,70)
i80=np.percentile(idade,80)
i90=np.percentile(idade,90)
i95=np.percentile(idade,95)
i99=np.percentile(idade,99)

print("\n[Ano 2018] Distribuição da idade da população brasileira")

print("\n10th Percentile: ",i10)
print("\n20th Percentile: ",i20)
print("\n25th Percentile: ",i25)
print("\n30th Percentile: ",i30)
print("\n40th Percentile: ",i40)
print("\n50th Percentile: ",i50)
print("\n60th Percentile: ",i60)
print("\n70th Percentile: ",i70)
print("\n80th Percentile: ",i80)
print("\n90th Percentile: ",i90)
print("\n95th Percentile: ",i95)
print("\n99th Percentile: ",i99)

# %%
rend = df_2018['Redimentos de trabalho'].dropna().to_list()

rp10=np.percentile(rend,10)
rp20=np.percentile(rend,20)
rp25=np.percentile(rend,25)
rp30=np.percentile(rend,30)
rp40=np.percentile(rend,40)
rp50=np.percentile(rend,50)
rp60=np.percentile(rend,60)
rp70=np.percentile(rend,70)
rp80=np.percentile(rend,80)
rp90=np.percentile(rend,90)
rp95=np.percentile(rend,95)
rp99=np.percentile(rend,99)

print("\n[Ano 2018] Redimento de trabalho mensal da população brasileira em reais")
print("Quantidade de respondentes", len(rend),"de",len(df_2018['Redimentos de trabalho'].to_list()))

print("\n10th Percentile: ",rp10)
print("\n20th Percentile: ",rp20)
print("\n25th Percentile: ",rp25)
print("\n30th Percentile: ",rp30)
print("\n40th Percentile: ",rp40)
print("\n50th Percentile: ",rp50)
print("\n60th Percentile: ",rp60)
print("\n70th Percentile: ",rp70)
print("\n80th Percentile: ",rp80)
print("\n90th Percentile: ",rp90)
print("\n95th Percentile: ",rp95)
print("\n99th Percentile: ",rp99)

# %%
df_2018['Ocupado/não'].value_counts()

# %%
df_2018['Profissao'].value_counts().head(20)

# %% [markdown]
# # [Amarelos]

# %%
df_asia = df_2018[df_2018['Cor'].str.contains('Amarela')]

# %%
df_asia.count()

# %%
df_asia['UF'].value_counts()

# %%
idade = df_asia['Idade'].to_list()

i10=np.percentile(idade,10)
i20=np.percentile(idade,20)
i25=np.percentile(idade,25)
i30=np.percentile(idade,30)
i40=np.percentile(idade,40)
i50=np.percentile(idade,50)
i60=np.percentile(idade,60)
i70=np.percentile(idade,70)
i80=np.percentile(idade,80)
i90=np.percentile(idade,90)
i95=np.percentile(idade,95)
i99=np.percentile(idade,99)

print("\n[Ano 2018] Distribuição da idade da população amarela")

print("\n10th Percentile: ",i10)
print("\n20th Percentile: ",i20)
print("\n25th Percentile: ",i25)
print("\n30th Percentile: ",i30)
print("\n40th Percentile: ",i40)
print("\n50th Percentile: ",i50)
print("\n60th Percentile: ",i60)
print("\n70th Percentile: ",i70)
print("\n80th Percentile: ",i80)
print("\n90th Percentile: ",i90)
print("\n95th Percentile: ",i95)
print("\n99th Percentile: ",i99)

# %%
df_asia['Educação feita'].value_counts()

# %%
df_asia['Educação atual'].value_counts()

# %%
df_asia['Economicamente ativa/não'].value_counts()

# %%
rend = df_asia['Redimentos de trabalho'].dropna().to_list()

rp10=np.percentile(rend,10)
rp20=np.percentile(rend,20)
rp25=np.percentile(rend,25)
rp30=np.percentile(rend,30)
rp40=np.percentile(rend,40)
rp50=np.percentile(rend,50)
rp60=np.percentile(rend,60)
rp70=np.percentile(rend,70)
rp80=np.percentile(rend,80)
rp90=np.percentile(rend,90)
rp95=np.percentile(rend,95)
rp99=np.percentile(rend,99)

print("\n[Ano 2018] Redimento de trabalho mensal da população amarela em reais")
print("Quantidade de respondentes", len(rend),"de",len(df_asia['Redimentos de trabalho'].to_list()))

print("\n10th Percentile: ",rp10)
print("\n20th Percentile: ",rp20)
print("\n25th Percentile: ",rp25)
print("\n30th Percentile: ",rp30)
print("\n40th Percentile: ",rp40)
print("\n50th Percentile: ",rp50)
print("\n60th Percentile: ",rp60)
print("\n70th Percentile: ",rp70)
print("\n80th Percentile: ",rp80)
print("\n90th Percentile: ",rp90)
print("\n95th Percentile: ",rp95)
print("\n99th Percentile: ",rp99)

# %%
df_asia['Le/escreve'].value_counts()

# %%
df_asia['Sexo'].value_counts()

# %%
df_asia['Ocupado/não'].value_counts()

# %%
df_asia['Profissao'].value_counts().head(20)

# %% [markdown]
# Mulher

# %%
df_asia_m = df_asia[df_asia['Sexo'].str.contains('Mulher')]
df_asia_m

# %%
idade = df_asia_m['Idade'].to_list()

i10=np.percentile(idade,10)
i20=np.percentile(idade,20)
i25=np.percentile(idade,25)
i30=np.percentile(idade,30)
i40=np.percentile(idade,40)
i50=np.percentile(idade,50)
i60=np.percentile(idade,60)
i70=np.percentile(idade,70)
i80=np.percentile(idade,80)
i90=np.percentile(idade,90)
i95=np.percentile(idade,95)
i99=np.percentile(idade,99)

print("\n[Ano 2018] Distribuição da idade das mulheres amarelas")

print("\n10th Percentile: ",i10)
print("\n20th Percentile: ",i20)
print("\n25th Percentile: ",i25)
print("\n30th Percentile: ",i30)
print("\n40th Percentile: ",i40)
print("\n50th Percentile: ",i50)
print("\n60th Percentile: ",i60)
print("\n70th Percentile: ",i70)
print("\n80th Percentile: ",i80)
print("\n90th Percentile: ",i90)
print("\n95th Percentile: ",i95)
print("\n99th Percentile: ",i99)

# %%
df_asia_m['Educação atual'].value_counts()

# %%
df_asia_m['Educação feita'].value_counts()

# %%
df_asia_m['Economicamente ativa/não'].value_counts()

# %%
rend = df_asia_m['Redimentos de trabalho'].dropna().to_list()

rp10=np.percentile(rend,10)
rp20=np.percentile(rend,20)
rp25=np.percentile(rend,25)
rp30=np.percentile(rend,30)
rp40=np.percentile(rend,40)
rp50=np.percentile(rend,50)
rp60=np.percentile(rend,60)
rp70=np.percentile(rend,70)
rp80=np.percentile(rend,80)
rp90=np.percentile(rend,90)
rp95=np.percentile(rend,95)
rp99=np.percentile(rend,99)

print("\n[Ano 2018] Redimento de trabalho mensal das mulheres amarelas em reais")
print("Quantidade de respondentes", len(rend),"de",len(df_asia_m['Redimentos de trabalho'].to_list()))

print("\n10th Percentile: ",rp10)
print("\n20th Percentile: ",rp20)
print("\n25th Percentile: ",rp25)
print("\n30th Percentile: ",rp30)
print("\n40th Percentile: ",rp40)
print("\n50th Percentile: ",rp50)
print("\n60th Percentile: ",rp60)
print("\n70th Percentile: ",rp70)
print("\n80th Percentile: ",rp80)
print("\n90th Percentile: ",rp90)
print("\n95th Percentile: ",rp95)
print("\n99th Percentile: ",rp99)

# %%
df_asia_m['Ocupado/não'].value_counts()

# %%
df_asia_m['Profissao'].value_counts().head(20)

# %% [markdown]
# Homens

# %%
df_asia_h = df_asia[df_asia['Sexo'].str.contains('Homem')]
df_asia_h

# %%
idade = df_asia_h['Idade'].to_list()

i10=np.percentile(idade,10)
i20=np.percentile(idade,20)
i25=np.percentile(idade,25)
i30=np.percentile(idade,30)
i40=np.percentile(idade,40)
i50=np.percentile(idade,50)
i60=np.percentile(idade,60)
i70=np.percentile(idade,70)
i80=np.percentile(idade,80)
i90=np.percentile(idade,90)
i95=np.percentile(idade,95)
i99=np.percentile(idade,99)

print("\n[Ano 2018] Distribuição da idade da população amarela")

print("\n10th Percentile: ",i10)
print("\n20th Percentile: ",i20)
print("\n25th Percentile: ",i25)
print("\n30th Percentile: ",i30)
print("\n40th Percentile: ",i40)
print("\n50th Percentile: ",i50)
print("\n60th Percentile: ",i60)
print("\n70th Percentile: ",i70)
print("\n80th Percentile: ",i80)
print("\n90th Percentile: ",i90)
print("\n95th Percentile: ",i95)
print("\n99th Percentile: ",i99)

# %%
df_asia_h['Educação feita'].value_counts()

# %%
df_asia_h['Educação atual'].value_counts()

# %%
df_asia_h['Economicamente ativa/não'].value_counts()

# %%
rend = df_asia_h['Redimentos de trabalho'].dropna().to_list()

rp10=np.percentile(rend,10)
rp20=np.percentile(rend,20)
rp25=np.percentile(rend,25)
rp30=np.percentile(rend,30)
rp40=np.percentile(rend,40)
rp50=np.percentile(rend,50)
rp60=np.percentile(rend,60)
rp70=np.percentile(rend,70)
rp80=np.percentile(rend,80)
rp90=np.percentile(rend,90)
rp95=np.percentile(rend,95)
rp99=np.percentile(rend,99)

print("\n[Ano 2018] Redimento de trabalho mensal dos homens amarelos em reais")
print("Quantidade de respondentes", len(rend),"de",len(df_asia_h['Redimentos de trabalho'].to_list()))

print("\n10th Percentile: ",rp10)
print("\n20th Percentile: ",rp20)
print("\n25th Percentile: ",rp25)
print("\n30th Percentile: ",rp30)
print("\n40th Percentile: ",rp40)
print("\n50th Percentile: ",rp50)
print("\n60th Percentile: ",rp60)
print("\n70th Percentile: ",rp70)
print("\n80th Percentile: ",rp80)
print("\n90th Percentile: ",rp90)
print("\n95th Percentile: ",rp95)
print("\n99th Percentile: ",rp99)

# %%
df_asia_h['Ocupado/não'].value_counts()

# %%
df_asia_h['Profissao'].value_counts().head(20)

# %% [markdown]
# # [2018] Explorando cargos ocupados pela população amarela na graduação

# %%
df_asia_p = df_asia[df_asia['Ocupado/não'].str.contains('Pessoas ocupadas',na=False)]
df_asia_p

# %%
graduando_p =  df_asia[df_asia['Educação atual'].str.contains('Superior - graduação',na=False)]
graduando_p

# %%
graduando_p['Economicamente ativa/não'].value_counts()

# %%
graduando_p['Profissao'].value_counts()

# %%
rend = graduando_p['Redimentos de trabalho'].dropna().to_list()

rp10=np.percentile(rend,10)
rp20=np.percentile(rend,20)
rp25=np.percentile(rend,25)
rp30=np.percentile(rend,30)
rp40=np.percentile(rend,40)
rp50=np.percentile(rend,50)
rp60=np.percentile(rend,60)
rp70=np.percentile(rend,70)
rp80=np.percentile(rend,80)
rp90=np.percentile(rend,90)
rp95=np.percentile(rend,95)
rp99=np.percentile(rend,99)

print("\n[Ano 2018] Redimento de trabalho mensal dos graduandos amarelos em reais")
print("Quantidade de respondentes", len(rend),"de",len(graduando_p['Redimentos de trabalho'].to_list()))

print("\n10th Percentile: ",rp10)
print("\n20th Percentile: ",rp20)
print("\n25th Percentile: ",rp25)
print("\n30th Percentile: ",rp30)
print("\n40th Percentile: ",rp40)
print("\n50th Percentile: ",rp50)
print("\n60th Percentile: ",rp60)
print("\n70th Percentile: ",rp70)
print("\n80th Percentile: ",rp80)
print("\n90th Percentile: ",rp90)
print("\n95th Percentile: ",rp95)
print("\n99th Percentile: ",rp99)

# %%
idade = graduando_p['Idade'].to_list()

i10=np.percentile(idade,10)
i20=np.percentile(idade,20)
i25=np.percentile(idade,25)
i30=np.percentile(idade,30)
i40=np.percentile(idade,40)
i50=np.percentile(idade,50)
i60=np.percentile(idade,60)
i70=np.percentile(idade,70)
i80=np.percentile(idade,80)
i90=np.percentile(idade,90)
i95=np.percentile(idade,95)
i99=np.percentile(idade,99)

print("\n[Ano 2018] Distribuição da idade da população amarela que ainda é graduando")

print("\n10th Percentile: ",i10)
print("\n20th Percentile: ",i20)
print("\n25th Percentile: ",i25)
print("\n30th Percentile: ",i30)
print("\n40th Percentile: ",i40)
print("\n50th Percentile: ",i50)
print("\n60th Percentile: ",i60)
print("\n70th Percentile: ",i70)
print("\n80th Percentile: ",i80)
print("\n90th Percentile: ",i90)
print("\n95th Percentile: ",i95)
print("\n99th Percentile: ",i99)

# %% [markdown]
# # [2018] Explorando cargos ocupados pela população amarela já graduados

# %%
graduando_pf =  df_asia[df_asia['Educação feita'].str.contains('Superior - graduação',na=False)]
graduando_pf

# %%
graduando_pf['Economicamente ativa/não'].value_counts()

# %%
graduando_pf['Profissao'].value_counts().head(30)

# %%
rend = graduando_pf['Redimentos de trabalho'].dropna().to_list()

rp10=np.percentile(rend,10)
rp20=np.percentile(rend,20)
rp25=np.percentile(rend,25)
rp30=np.percentile(rend,30)
rp40=np.percentile(rend,40)
rp50=np.percentile(rend,50)
rp60=np.percentile(rend,60)
rp70=np.percentile(rend,70)
rp80=np.percentile(rend,80)
rp90=np.percentile(rend,90)
rp95=np.percentile(rend,95)
rp99=np.percentile(rend,99)

print("\n[Ano 2018] Redimento de trabalho mensal dos já graduados amarelos em reais")
print("Quantidade de respondentes", len(rend),"de",len(graduando_pf['Redimentos de trabalho'].to_list()))

print("\n10th Percentile: ",rp10)
print("\n20th Percentile: ",rp20)
print("\n25th Percentile: ",rp25)
print("\n30th Percentile: ",rp30)
print("\n40th Percentile: ",rp40)
print("\n50th Percentile: ",rp50)
print("\n60th Percentile: ",rp60)
print("\n70th Percentile: ",rp70)
print("\n80th Percentile: ",rp80)
print("\n90th Percentile: ",rp90)
print("\n95th Percentile: ",rp95)
print("\n99th Percentile: ",rp99)

# %%
idade = graduando_pf['Idade'].to_list()

i10=np.percentile(idade,10)
i20=np.percentile(idade,20)
i25=np.percentile(idade,25)
i30=np.percentile(idade,30)
i40=np.percentile(idade,40)
i50=np.percentile(idade,50)
i60=np.percentile(idade,60)
i70=np.percentile(idade,70)
i80=np.percentile(idade,80)
i90=np.percentile(idade,90)
i95=np.percentile(idade,95)
i99=np.percentile(idade,99)

print("\n[Ano 2018] Distribuição da idade da população amarela que já se formou")

print("\n10th Percentile: ",i10)
print("\n20th Percentile: ",i20)
print("\n25th Percentile: ",i25)
print("\n30th Percentile: ",i30)
print("\n40th Percentile: ",i40)
print("\n50th Percentile: ",i50)
print("\n60th Percentile: ",i60)
print("\n70th Percentile: ",i70)
print("\n80th Percentile: ",i80)
print("\n90th Percentile: ",i90)
print("\n95th Percentile: ",i95)
print("\n99th Percentile: ",i99)

# %% [markdown]
# # ANO 2017

# %%
df_2017.count()

# %%
df_2017['Economicamente ativa/não'].value_counts()

# %%
df_2017['Educação atual'].value_counts()

# %%
df_2017['Educação feita'].value_counts()

# %%
df_2017['Cor'].value_counts()

# %%
idade = df_2017['Idade'].to_list()

i10=np.percentile(idade,10)
i20=np.percentile(idade,20)
i25=np.percentile(idade,25)
i30=np.percentile(idade,30)
i40=np.percentile(idade,40)
i50=np.percentile(idade,50)
i60=np.percentile(idade,60)
i70=np.percentile(idade,70)
i80=np.percentile(idade,80)
i90=np.percentile(idade,90)
i95=np.percentile(idade,95)
i99=np.percentile(idade,99)

print("\n[Ano 2017] Distribuição da idade da população brasileira")

print("\n10th Percentile: ",i10)
print("\n20th Percentile: ",i20)
print("\n25th Percentile: ",i25)
print("\n30th Percentile: ",i30)
print("\n40th Percentile: ",i40)
print("\n50th Percentile: ",i50)
print("\n60th Percentile: ",i60)
print("\n70th Percentile: ",i70)
print("\n80th Percentile: ",i80)
print("\n90th Percentile: ",i90)
print("\n95th Percentile: ",i95)
print("\n99th Percentile: ",i99)

# %%
rend = df_2017['Redimentos de trabalho'].dropna().to_list()

rp10=np.percentile(rend,10)
rp20=np.percentile(rend,20)
rp25=np.percentile(rend,25)
rp30=np.percentile(rend,30)
rp40=np.percentile(rend,40)
rp50=np.percentile(rend,50)
rp60=np.percentile(rend,60)
rp70=np.percentile(rend,70)
rp80=np.percentile(rend,80)
rp90=np.percentile(rend,90)
rp95=np.percentile(rend,95)
rp99=np.percentile(rend,99)

print("\n[Ano 2017] Redimento de trabalho mensal da população brasileira em reais")
print("Quantidade de respondentes", len(rend),"de",len(df_2017['Redimentos de trabalho'].to_list()))

print("\n10th Percentile: ",rp10)
print("\n20th Percentile: ",rp20)
print("\n25th Percentile: ",rp25)
print("\n30th Percentile: ",rp30)
print("\n40th Percentile: ",rp40)
print("\n50th Percentile: ",rp50)
print("\n60th Percentile: ",rp60)
print("\n70th Percentile: ",rp70)
print("\n80th Percentile: ",rp80)
print("\n90th Percentile: ",rp90)
print("\n95th Percentile: ",rp95)
print("\n99th Percentile: ",rp99)

# %% [markdown]
# # [AMARELOS]

# %%
df_asia = df_2017[df_2017['Cor'].str.contains('Amarela')]

# %%
df_asia.count()

# %%
df_asia['UF'].value_counts()

# %%
idade = df_asia['Idade'].to_list()

i10=np.percentile(idade,10)
i20=np.percentile(idade,20)
i25=np.percentile(idade,25)
i30=np.percentile(idade,30)
i40=np.percentile(idade,40)
i50=np.percentile(idade,50)
i60=np.percentile(idade,60)
i70=np.percentile(idade,70)
i80=np.percentile(idade,80)
i90=np.percentile(idade,90)
i95=np.percentile(idade,95)
i99=np.percentile(idade,99)

print("\n[Ano 2017] Distribuição da idade da população amarela")

print("\n10th Percentile: ",i10)
print("\n20th Percentile: ",i20)
print("\n25th Percentile: ",i25)
print("\n30th Percentile: ",i30)
print("\n40th Percentile: ",i40)
print("\n50th Percentile: ",i50)
print("\n60th Percentile: ",i60)
print("\n70th Percentile: ",i70)
print("\n80th Percentile: ",i80)
print("\n90th Percentile: ",i90)
print("\n95th Percentile: ",i95)
print("\n99th Percentile: ",i99)

# %%
df_asia['Educação atual'].value_counts()

# %%
df_asia['Educação feita'].value_counts()

# %%
df_asia['Economicamente ativa/não'].value_counts()

# %%
rend = df_asia['Redimentos de trabalho'].dropna().to_list()

rp10=np.percentile(rend,10)
rp20=np.percentile(rend,20)
rp25=np.percentile(rend,25)
rp30=np.percentile(rend,30)
rp40=np.percentile(rend,40)
rp50=np.percentile(rend,50)
rp60=np.percentile(rend,60)
rp70=np.percentile(rend,70)
rp80=np.percentile(rend,80)
rp90=np.percentile(rend,90)
rp95=np.percentile(rend,95)
rp99=np.percentile(rend,99)

print("\n[Ano 2017] Redimento de trabalho mensal da população amarela em reais")
print("Quantidade de respondentes", len(rend),"de",len(df_asia['Redimentos de trabalho'].to_list()))

print("\n10th Percentile: ",rp10)
print("\n20th Percentile: ",rp20)
print("\n25th Percentile: ",rp25)
print("\n30th Percentile: ",rp30)
print("\n40th Percentile: ",rp40)
print("\n50th Percentile: ",rp50)
print("\n60th Percentile: ",rp60)
print("\n70th Percentile: ",rp70)
print("\n80th Percentile: ",rp80)
print("\n90th Percentile: ",rp90)
print("\n95th Percentile: ",rp95)
print("\n99th Percentile: ",rp99)

# %%
df_asia['Sexo'].value_counts()

# %%
df_asia['Ocupado/não'].value_counts()

# %%
df_asia['Profissao'].value_counts().head(20)

# %% [markdown]
# Mulher

# %%
df_asia_m = df_asia[df_asia['Sexo'].str.contains('Mulher')]

# %%
idade = df_asia_m['Idade'].to_list()

i10=np.percentile(idade,10)
i20=np.percentile(idade,20)
i25=np.percentile(idade,25)
i30=np.percentile(idade,30)
i40=np.percentile(idade,40)
i50=np.percentile(idade,50)
i60=np.percentile(idade,60)
i70=np.percentile(idade,70)
i80=np.percentile(idade,80)
i90=np.percentile(idade,90)
i95=np.percentile(idade,95)
i99=np.percentile(idade,99)

print("\n[Ano 2017] Distribuição da idade das mulheres amarelas")

print("\n10th Percentile: ",i10)
print("\n20th Percentile: ",i20)
print("\n25th Percentile: ",i25)
print("\n30th Percentile: ",i30)
print("\n40th Percentile: ",i40)
print("\n50th Percentile: ",i50)
print("\n60th Percentile: ",i60)
print("\n70th Percentile: ",i70)
print("\n80th Percentile: ",i80)
print("\n90th Percentile: ",i90)
print("\n95th Percentile: ",i95)
print("\n99th Percentile: ",i99)

# %%
df_asia_m['Educação atual'].value_counts()

# %%
df_asia_m['Educação feita'].value_counts()

# %%
df_asia_m['Economicamente ativa/não'].value_counts()

# %%
rend = df_asia_m['Redimentos de trabalho'].dropna().to_list()

rp10=np.percentile(rend,10)
rp20=np.percentile(rend,20)
rp25=np.percentile(rend,25)
rp30=np.percentile(rend,30)
rp40=np.percentile(rend,40)
rp50=np.percentile(rend,50)
rp60=np.percentile(rend,60)
rp70=np.percentile(rend,70)
rp80=np.percentile(rend,80)
rp90=np.percentile(rend,90)
rp95=np.percentile(rend,95)
rp99=np.percentile(rend,99)

print("\n[Ano 2017] Redimento de trabalho mensal das mulheres amarelas em reais")
print("Quantidade de respondentes", len(rend),"de",len(df_asia_m['Redimentos de trabalho'].to_list()))

print("\n10th Percentile: ",rp10)
print("\n20th Percentile: ",rp20)
print("\n25th Percentile: ",rp25)
print("\n30th Percentile: ",rp30)
print("\n40th Percentile: ",rp40)
print("\n50th Percentile: ",rp50)
print("\n60th Percentile: ",rp60)
print("\n70th Percentile: ",rp70)
print("\n80th Percentile: ",rp80)
print("\n90th Percentile: ",rp90)
print("\n95th Percentile: ",rp95)
print("\n99th Percentile: ",rp99)

# %%
df_asia_m['Profissao'].value_counts().head(20)

# %%
df_asia_m['Ocupado/não'].value_counts()

# %% [markdown]
# Homem

# %%
df_asia_h = df_asia[df_asia['Sexo'].str.contains('Homem')]

# %%
idade = df_asia_h['Idade'].to_list()

i10=np.percentile(idade,10)
i20=np.percentile(idade,20)
i25=np.percentile(idade,25)
i30=np.percentile(idade,30)
i40=np.percentile(idade,40)
i50=np.percentile(idade,50)
i60=np.percentile(idade,60)
i70=np.percentile(idade,70)
i80=np.percentile(idade,80)
i90=np.percentile(idade,90)
i95=np.percentile(idade,95)
i99=np.percentile(idade,99)

print("\n[Ano 2017] Distribuição da idade da população amarela masculina")

print("\n10th Percentile: ",i10)
print("\n20th Percentile: ",i20)
print("\n25th Percentile: ",i25)
print("\n30th Percentile: ",i30)
print("\n40th Percentile: ",i40)
print("\n50th Percentile: ",i50)
print("\n60th Percentile: ",i60)
print("\n70th Percentile: ",i70)
print("\n80th Percentile: ",i80)
print("\n90th Percentile: ",i90)
print("\n95th Percentile: ",i95)
print("\n99th Percentile: ",i99)

# %%
df_asia_h['Educação feita'].value_counts()

# %%
df_asia_h['Educação atual'].value_counts()

# %%
rend = df_asia_h['Redimentos de trabalho'].dropna().to_list()

rp10=np.percentile(rend,10)
rp20=np.percentile(rend,20)
rp25=np.percentile(rend,25)
rp30=np.percentile(rend,30)
rp40=np.percentile(rend,40)
rp50=np.percentile(rend,50)
rp60=np.percentile(rend,60)
rp70=np.percentile(rend,70)
rp80=np.percentile(rend,80)
rp90=np.percentile(rend,90)
rp95=np.percentile(rend,95)
rp99=np.percentile(rend,99)

print("\n[Ano 2017] Redimento de trabalho mensal dos homens amarelos em reais")
print("Quantidade de respondentes", len(rend),"de",len(df_asia_h['Redimentos de trabalho'].to_list()))

print("\n10th Percentile: ",rp10)
print("\n20th Percentile: ",rp20)
print("\n25th Percentile: ",rp25)
print("\n30th Percentile: ",rp30)
print("\n40th Percentile: ",rp40)
print("\n50th Percentile: ",rp50)
print("\n60th Percentile: ",rp60)
print("\n70th Percentile: ",rp70)
print("\n80th Percentile: ",rp80)
print("\n90th Percentile: ",rp90)
print("\n95th Percentile: ",rp95)
print("\n99th Percentile: ",rp99)

# %%
df_asia_h['Ocupado/não'].value_counts()

# %%
df_asia_h['Profissao'].value_counts().head(20)

# %%
df_asia_h['Economicamente ativa/não'].value_counts()

# %% [markdown]
# # [2017] Explorando cargos ocupados pela população amarela na graduação

# %%
df_asia_p = df_asia[df_asia['Ocupado/não'].str.contains('Pessoas ocupadas',na=False)]
graduando_p =  df_asia[df_asia['Educação atual'].str.contains('Superior - graduação',na=False)]

# %%
graduando_p['Economicamente ativa/não'].value_counts()

# %%
graduando_p['Profissao'].value_counts()

# %%
rend = graduando_p['Redimentos de trabalho'].dropna().to_list()

rp10=np.percentile(rend,10)
rp20=np.percentile(rend,20)
rp25=np.percentile(rend,25)
rp30=np.percentile(rend,30)
rp40=np.percentile(rend,40)
rp50=np.percentile(rend,50)
rp60=np.percentile(rend,60)
rp70=np.percentile(rend,70)
rp80=np.percentile(rend,80)
rp90=np.percentile(rend,90)
rp95=np.percentile(rend,95)
rp99=np.percentile(rend,99)

print("\n[Ano 2017] Redimento de trabalho mensal dos graduandos amarelos em reais")
print("Quantidade de respondentes", len(rend),"de",len(graduando_p['Redimentos de trabalho'].to_list()))

print("\n10th Percentile: ",rp10)
print("\n20th Percentile: ",rp20)
print("\n25th Percentile: ",rp25)
print("\n30th Percentile: ",rp30)
print("\n40th Percentile: ",rp40)
print("\n50th Percentile: ",rp50)
print("\n60th Percentile: ",rp60)
print("\n70th Percentile: ",rp70)
print("\n80th Percentile: ",rp80)
print("\n90th Percentile: ",rp90)
print("\n95th Percentile: ",rp95)
print("\n99th Percentile: ",rp99)

# %%
idade = graduando_p['Idade'].to_list()

i10=np.percentile(idade,10)
i20=np.percentile(idade,20)
i25=np.percentile(idade,25)
i30=np.percentile(idade,30)
i40=np.percentile(idade,40)
i50=np.percentile(idade,50)
i60=np.percentile(idade,60)
i70=np.percentile(idade,70)
i80=np.percentile(idade,80)
i90=np.percentile(idade,90)
i95=np.percentile(idade,95)
i99=np.percentile(idade,99)

print("\n[Ano 2017] Distribuição da idade da população amarela que ainda é graduando")

print("\n10th Percentile: ",i10)
print("\n20th Percentile: ",i20)
print("\n25th Percentile: ",i25)
print("\n30th Percentile: ",i30)
print("\n40th Percentile: ",i40)
print("\n50th Percentile: ",i50)
print("\n60th Percentile: ",i60)
print("\n70th Percentile: ",i70)
print("\n80th Percentile: ",i80)
print("\n90th Percentile: ",i90)
print("\n95th Percentile: ",i95)
print("\n99th Percentile: ",i99)

# %% [markdown]
# # [2017] Explorando cargos ocupados pela população amarela já graduados

# %%
graduando_pf =  df_asia[df_asia['Educação feita'].str.contains('Superior - graduação',na=False)]

# %%
graduando_pf['Economicamente ativa/não'].value_counts()

# %%
graduando_pf['Profissao'].value_counts().head(30)

# %%
rend = graduando_pf['Redimentos de trabalho'].dropna().to_list()

rp10=np.percentile(rend,10)
rp20=np.percentile(rend,20)
rp25=np.percentile(rend,25)
rp30=np.percentile(rend,30)
rp40=np.percentile(rend,40)
rp50=np.percentile(rend,50)
rp60=np.percentile(rend,60)
rp70=np.percentile(rend,70)
rp80=np.percentile(rend,80)
rp90=np.percentile(rend,90)
rp95=np.percentile(rend,95)
rp99=np.percentile(rend,99)

print("\n[Ano 2017] Redimento de trabalho mensal dos já graduados amarelos em reais")
print("Quantidade de respondentes", len(rend),"de",len(graduando_pf['Redimentos de trabalho'].to_list()))

print("\n10th Percentile: ",rp10)
print("\n20th Percentile: ",rp20)
print("\n25th Percentile: ",rp25)
print("\n30th Percentile: ",rp30)
print("\n40th Percentile: ",rp40)
print("\n50th Percentile: ",rp50)
print("\n60th Percentile: ",rp60)
print("\n70th Percentile: ",rp70)
print("\n80th Percentile: ",rp80)
print("\n90th Percentile: ",rp90)
print("\n95th Percentile: ",rp95)
print("\n99th Percentile: ",rp99)

# %%
idade = graduando_pf['Idade'].to_list()

i10=np.percentile(idade,10)
i20=np.percentile(idade,20)
i25=np.percentile(idade,25)
i30=np.percentile(idade,30)
i40=np.percentile(idade,40)
i50=np.percentile(idade,50)
i60=np.percentile(idade,60)
i70=np.percentile(idade,70)
i80=np.percentile(idade,80)
i90=np.percentile(idade,90)
i95=np.percentile(idade,95)
i99=np.percentile(idade,99)

print("\n[Ano 2017] Distribuição da idade da população amarela que já se formou")
print("\n10th Percentile: ",i10)
print("\n20th Percentile: ",i20)
print("\n25th Percentile: ",i25)
print("\n30th Percentile: ",i30)
print("\n40th Percentile: ",i40)
print("\n50th Percentile: ",i50)
print("\n60th Percentile: ",i60)
print("\n70th Percentile: ",i70)
print("\n80th Percentile: ",i80)
print("\n90th Percentile: ",i90)
print("\n95th Percentile: ",i95)
print("\n99th Percentile: ",i99)

# %% [markdown]
# # ANO 2016

# %%
df_2016.count()

# %%
df_2016['Economicamente ativa/não'].value_counts()

# %%
df_2016['Educação atual'].value_counts()

# %%
df_2016['Educação feita'].value_counts()

# %%
df_2016['Cor'].value_counts()

# %%
idade = df_2016['Idade'].to_list()

i10=np.percentile(idade,10)
i20=np.percentile(idade,20)
i25=np.percentile(idade,25)
i30=np.percentile(idade,30)
i40=np.percentile(idade,40)
i50=np.percentile(idade,50)
i60=np.percentile(idade,60)
i70=np.percentile(idade,70)
i80=np.percentile(idade,80)
i90=np.percentile(idade,90)
i95=np.percentile(idade,95)
i99=np.percentile(idade,99)

print("\n[Ano 2016] Distribuição da idade da população brasileira")

print("\n10th Percentile: ",i10)
print("\n20th Percentile: ",i20)
print("\n25th Percentile: ",i25)
print("\n30th Percentile: ",i30)
print("\n40th Percentile: ",i40)
print("\n50th Percentile: ",i50)
print("\n60th Percentile: ",i60)
print("\n70th Percentile: ",i70)
print("\n80th Percentile: ",i80)
print("\n90th Percentile: ",i90)
print("\n95th Percentile: ",i95)
print("\n99th Percentile: ",i99)

# %%
rend = df_2016['Redimentos de trabalho'].dropna().to_list()

rp10=np.percentile(rend,10)
rp20=np.percentile(rend,20)
rp25=np.percentile(rend,25)
rp30=np.percentile(rend,30)
rp40=np.percentile(rend,40)
rp50=np.percentile(rend,50)
rp60=np.percentile(rend,60)
rp70=np.percentile(rend,70)
rp80=np.percentile(rend,80)
rp90=np.percentile(rend,90)
rp95=np.percentile(rend,95)
rp99=np.percentile(rend,99)

print("\n[Ano 2016] Redimento de trabalho mensal da população brasileira em reais")
print("Quantidade de respondentes", len(rend),"de",len(df_2017['Redimentos de trabalho'].to_list()))

print("\n10th Percentile: ",rp10)
print("\n20th Percentile: ",rp20)
print("\n25th Percentile: ",rp25)
print("\n30th Percentile: ",rp30)
print("\n40th Percentile: ",rp40)
print("\n50th Percentile: ",rp50)
print("\n60th Percentile: ",rp60)
print("\n70th Percentile: ",rp70)
print("\n80th Percentile: ",rp80)
print("\n90th Percentile: ",rp90)
print("\n95th Percentile: ",rp95)
print("\n99th Percentile: ",rp99)

# %% [markdown]
# # [AMARELOS]

# %%
df_asia = df_2016[df_2016['Cor'].str.contains('Amarela')]

# %%
df_asia.count()

# %%
df_asia['UF'].value_counts()

# %%
idade = df_asia['Idade'].to_list()

i10=np.percentile(idade,10)
i20=np.percentile(idade,20)
i25=np.percentile(idade,25)
i30=np.percentile(idade,30)
i40=np.percentile(idade,40)
i50=np.percentile(idade,50)
i60=np.percentile(idade,60)
i70=np.percentile(idade,70)
i80=np.percentile(idade,80)
i90=np.percentile(idade,90)
i95=np.percentile(idade,95)
i99=np.percentile(idade,99)

print("\n[Ano 2016] Distribuição da idade da população amarela")

print("\n10th Percentile: ",i10)
print("\n20th Percentile: ",i20)
print("\n25th Percentile: ",i25)
print("\n30th Percentile: ",i30)
print("\n40th Percentile: ",i40)
print("\n50th Percentile: ",i50)
print("\n60th Percentile: ",i60)
print("\n70th Percentile: ",i70)
print("\n80th Percentile: ",i80)
print("\n90th Percentile: ",i90)
print("\n95th Percentile: ",i95)
print("\n99th Percentile: ",i99)

# %%
df_asia['Educação atual'].value_counts()

# %%
df_asia['Educação feita'].value_counts()

# %%
df_asia['Economicamente ativa/não'].value_counts()

# %%
rend = df_asia['Redimentos de trabalho'].dropna().to_list()

rp10=np.percentile(rend,10)
rp20=np.percentile(rend,20)
rp25=np.percentile(rend,25)
rp30=np.percentile(rend,30)
rp40=np.percentile(rend,40)
rp50=np.percentile(rend,50)
rp60=np.percentile(rend,60)
rp70=np.percentile(rend,70)
rp80=np.percentile(rend,80)
rp90=np.percentile(rend,90)
rp95=np.percentile(rend,95)
rp99=np.percentile(rend,99)

print("\n[Ano 2016] Redimento de trabalho mensal da população amarela em reais")
print("Quantidade de respondentes", len(rend),"de",len(df_asia['Redimentos de trabalho'].to_list()))

print("\n10th Percentile: ",rp10)
print("\n20th Percentile: ",rp20)
print("\n25th Percentile: ",rp25)
print("\n30th Percentile: ",rp30)
print("\n40th Percentile: ",rp40)
print("\n50th Percentile: ",rp50)
print("\n60th Percentile: ",rp60)
print("\n70th Percentile: ",rp70)
print("\n80th Percentile: ",rp80)
print("\n90th Percentile: ",rp90)
print("\n95th Percentile: ",rp95)
print("\n99th Percentile: ",rp99)

# %%
df_asia['Sexo'].value_counts()

# %%
df_asia['Ocupado/não'].value_counts()

# %%
df_asia['Profissao'].value_counts().head(20)

# %% [markdown]
# Mulher

# %%
df_asia_m = df_asia[df_asia['Sexo'].str.contains('Mulher')]

# %%
idade = df_asia_m['Idade'].to_list()

i10=np.percentile(idade,10)
i20=np.percentile(idade,20)
i25=np.percentile(idade,25)
i30=np.percentile(idade,30)
i40=np.percentile(idade,40)
i50=np.percentile(idade,50)
i60=np.percentile(idade,60)
i70=np.percentile(idade,70)
i80=np.percentile(idade,80)
i90=np.percentile(idade,90)
i95=np.percentile(idade,95)
i99=np.percentile(idade,99)

print("\n[Ano 2016] Distribuição da idade das mulheres amarelas")

print("\n10th Percentile: ",i10)
print("\n20th Percentile: ",i20)
print("\n25th Percentile: ",i25)
print("\n30th Percentile: ",i30)
print("\n40th Percentile: ",i40)
print("\n50th Percentile: ",i50)
print("\n60th Percentile: ",i60)
print("\n70th Percentile: ",i70)
print("\n80th Percentile: ",i80)
print("\n90th Percentile: ",i90)
print("\n95th Percentile: ",i95)
print("\n99th Percentile: ",i99)

# %%
df_asia_m['Educação atual'].value_counts()

# %%
df_asia_m['Educação feita'].value_counts()

# %%
df_asia_m['Economicamente ativa/não'].value_counts()

# %%
df_asia_m['Ocupado/não'].value_counts()

# %%
rend = df_asia_m['Redimentos de trabalho'].dropna().to_list()

rp10=np.percentile(rend,10)
rp20=np.percentile(rend,20)
rp25=np.percentile(rend,25)
rp30=np.percentile(rend,30)
rp40=np.percentile(rend,40)
rp50=np.percentile(rend,50)
rp60=np.percentile(rend,60)
rp70=np.percentile(rend,70)
rp80=np.percentile(rend,80)
rp90=np.percentile(rend,90)
rp95=np.percentile(rend,95)
rp99=np.percentile(rend,99)

print("\n[Ano 2016] Redimento de trabalho mensal das mulheres amarelas em reais")
print("Quantidade de respondentes", len(rend),"de",len(df_asia_m['Redimentos de trabalho'].to_list()))

print("\n10th Percentile: ",rp10)
print("\n20th Percentile: ",rp20)
print("\n25th Percentile: ",rp25)
print("\n30th Percentile: ",rp30)
print("\n40th Percentile: ",rp40)
print("\n50th Percentile: ",rp50)
print("\n60th Percentile: ",rp60)
print("\n70th Percentile: ",rp70)
print("\n80th Percentile: ",rp80)
print("\n90th Percentile: ",rp90)
print("\n95th Percentile: ",rp95)
print("\n99th Percentile: ",rp99)

# %%
df_asia_m['Profissao'].value_counts().head(20)

# %% [markdown]
# Homem

# %%
df_asia_h = df_asia[df_asia['Sexo'].str.contains('Homem')]

# %%
idade = df_asia_h['Idade'].to_list()

i10=np.percentile(idade,10)
i20=np.percentile(idade,20)
i25=np.percentile(idade,25)
i30=np.percentile(idade,30)
i40=np.percentile(idade,40)
i50=np.percentile(idade,50)
i60=np.percentile(idade,60)
i70=np.percentile(idade,70)
i80=np.percentile(idade,80)
i90=np.percentile(idade,90)
i95=np.percentile(idade,95)
i99=np.percentile(idade,99)

print("\n[Ano 2016] Distribuição da idade da população amarela masculina")

print("\n10th Percentile: ",i10)
print("\n20th Percentile: ",i20)
print("\n25th Percentile: ",i25)
print("\n30th Percentile: ",i30)
print("\n40th Percentile: ",i40)
print("\n50th Percentile: ",i50)
print("\n60th Percentile: ",i60)
print("\n70th Percentile: ",i70)
print("\n80th Percentile: ",i80)
print("\n90th Percentile: ",i90)
print("\n95th Percentile: ",i95)
print("\n99th Percentile: ",i99)

# %%
df_asia_h['Educação feita'].value_counts()

# %%
df_asia_h['Educação atual'].value_counts()

# %%
rend = df_asia_h['Redimentos de trabalho'].dropna().to_list()

rp10=np.percentile(rend,10)
rp20=np.percentile(rend,20)
rp25=np.percentile(rend,25)
rp30=np.percentile(rend,30)
rp40=np.percentile(rend,40)
rp50=np.percentile(rend,50)
rp60=np.percentile(rend,60)
rp70=np.percentile(rend,70)
rp80=np.percentile(rend,80)
rp90=np.percentile(rend,90)
rp95=np.percentile(rend,95)
rp99=np.percentile(rend,99)

print("\n[Ano 2016] Redimento de trabalho mensal dos homens amarelos em reais")
print("Quantidade de respondentes", len(rend),"de",len(df_asia_h['Redimentos de trabalho'].to_list()))

print("\n10th Percentile: ",rp10)
print("\n20th Percentile: ",rp20)
print("\n25th Percentile: ",rp25)
print("\n30th Percentile: ",rp30)
print("\n40th Percentile: ",rp40)
print("\n50th Percentile: ",rp50)
print("\n60th Percentile: ",rp60)
print("\n70th Percentile: ",rp70)
print("\n80th Percentile: ",rp80)
print("\n90th Percentile: ",rp90)
print("\n95th Percentile: ",rp95)
print("\n99th Percentile: ",rp99)

# %%
df_asia_h['Ocupado/não'].value_counts()

# %%
df_asia_h['Economicamente ativa/não'].value_counts()

# %%
df_asia_h['Profissao'].value_counts().head(20)

# %% [markdown]
# # [2016] Explorando cargos ocupados pela população amarela na graduação

# %%
df_asia_p = df_asia[df_asia['Ocupado/não'].str.contains('Pessoas ocupadas',na=False)]
graduando_p =  df_asia[df_asia['Educação atual'].str.contains('Superior - graduação',na=False)]

# %%
graduando_p['Economicamente ativa/não'].value_counts()

# %%
graduando_p['Profissao'].value_counts()

# %%
rend = graduando_p['Redimentos de trabalho'].dropna().to_list()

rp10=np.percentile(rend,10)
rp20=np.percentile(rend,20)
rp25=np.percentile(rend,25)
rp30=np.percentile(rend,30)
rp40=np.percentile(rend,40)
rp50=np.percentile(rend,50)
rp60=np.percentile(rend,60)
rp70=np.percentile(rend,70)
rp80=np.percentile(rend,80)
rp90=np.percentile(rend,90)
rp95=np.percentile(rend,95)
rp99=np.percentile(rend,99)

print("\n[Ano 2016] Redimento de trabalho mensal dos graduandos amarelos em reais")
print("Quantidade de respondentes", len(rend),"de",len(graduando_p['Redimentos de trabalho'].to_list()))

print("\n10th Percentile: ",rp10)
print("\n20th Percentile: ",rp20)
print("\n25th Percentile: ",rp25)
print("\n30th Percentile: ",rp30)
print("\n40th Percentile: ",rp40)
print("\n50th Percentile: ",rp50)
print("\n60th Percentile: ",rp60)
print("\n70th Percentile: ",rp70)
print("\n80th Percentile: ",rp80)
print("\n90th Percentile: ",rp90)
print("\n95th Percentile: ",rp95)
print("\n99th Percentile: ",rp99)

# %%
idade = graduando_p['Idade'].to_list()

i10=np.percentile(idade,10)
i20=np.percentile(idade,20)
i25=np.percentile(idade,25)
i30=np.percentile(idade,30)
i40=np.percentile(idade,40)
i50=np.percentile(idade,50)
i60=np.percentile(idade,60)
i70=np.percentile(idade,70)
i80=np.percentile(idade,80)
i90=np.percentile(idade,90)
i95=np.percentile(idade,95)
i99=np.percentile(idade,99)

print("\n[Ano 2016] Distribuição da idade da população amarela que ainda é graduando")

print("\n10th Percentile: ",i10)
print("\n20th Percentile: ",i20)
print("\n25th Percentile: ",i25)
print("\n30th Percentile: ",i30)
print("\n40th Percentile: ",i40)
print("\n50th Percentile: ",i50)
print("\n60th Percentile: ",i60)
print("\n70th Percentile: ",i70)
print("\n80th Percentile: ",i80)
print("\n90th Percentile: ",i90)
print("\n95th Percentile: ",i95)
print("\n99th Percentile: ",i99)

# %% [markdown]
# # [2016] Explorando cargos ocupados pela população amarela já graduados

# %%
graduando_pf =  df_asia[df_asia['Educação feita'].str.contains('Superior - graduação',na=False)]

# %%
graduando_pf['Economicamente ativa/não'].value_counts()

# %%
graduando_pf['Profissao'].value_counts().head(30)

# %%
rend = graduando_pf['Redimentos de trabalho'].dropna().to_list()

rp10=np.percentile(rend,10)
rp20=np.percentile(rend,20)
rp25=np.percentile(rend,25)
rp30=np.percentile(rend,30)
rp40=np.percentile(rend,40)
rp50=np.percentile(rend,50)
rp60=np.percentile(rend,60)
rp70=np.percentile(rend,70)
rp80=np.percentile(rend,80)
rp90=np.percentile(rend,90)
rp95=np.percentile(rend,95)
rp99=np.percentile(rend,99)

print("\n[Ano 2016] Redimento de trabalho mensal dos já graduados amarelos em reais")
print("Quantidade de respondentes", len(rend),"de",len(graduando_pf['Redimentos de trabalho'].to_list()))

print("\n10th Percentile: ",rp10)
print("\n20th Percentile: ",rp20)
print("\n25th Percentile: ",rp25)
print("\n30th Percentile: ",rp30)
print("\n40th Percentile: ",rp40)
print("\n50th Percentile: ",rp50)
print("\n60th Percentile: ",rp60)
print("\n70th Percentile: ",rp70)
print("\n80th Percentile: ",rp80)
print("\n90th Percentile: ",rp90)
print("\n95th Percentile: ",rp95)
print("\n99th Percentile: ",rp99)

# %%
idade = graduando_pf['Idade'].to_list()

i10=np.percentile(idade,10)
i20=np.percentile(idade,20)
i25=np.percentile(idade,25)
i30=np.percentile(idade,30)
i40=np.percentile(idade,40)
i50=np.percentile(idade,50)
i60=np.percentile(idade,60)
i70=np.percentile(idade,70)
i80=np.percentile(idade,80)
i90=np.percentile(idade,90)
i95=np.percentile(idade,95)
i99=np.percentile(idade,99)

print("\n[Ano 2016] Distribuição da idade da população amarela que já se formou")
print("\n10th Percentile: ",i10)
print("\n20th Percentile: ",i20)
print("\n25th Percentile: ",i25)
print("\n30th Percentile: ",i30)
print("\n40th Percentile: ",i40)
print("\n50th Percentile: ",i50)
print("\n60th Percentile: ",i60)
print("\n70th Percentile: ",i70)
print("\n80th Percentile: ",i80)
print("\n90th Percentile: ",i90)
print("\n95th Percentile: ",i95)
print("\n99th Percentile: ",i99)
